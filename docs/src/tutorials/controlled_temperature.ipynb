# %%
using ModelingToolkit, OrdinaryDiffEq, Plots
using ModelingToolkit: t_nounits as t
using ModelingToolkitStandardLibrary: Thermal, Electrical

# %%
@mtkmodel ControlledTemperature begin
    @parameters begin
        
    end

    @variables begin
        
    end

    @components begin
        voltage = Voltage()
        resistor = HeatingResistor()

    end

    @equations begin
        connect(voltage.n, resistor.n)
        connect(voltage.n, ground.p)
        connect(resistor.HeatPort, )
    end
end

# %% [markdown]
# The following components need to be added:
#
# 1. Analog switch
# 2. Constant voltage (and current)
# 3. HeatingResistor --> Resistor
